# %%
from __future__ import absolute_import, division, print_function


import collections
import functools
import numpy as np
import os
import tensorflow as tf
from tensorflow.python.keras.optimizer_v2 import gradient_descent
import time

from tensorflow_federated import python as tff

nest = tf.contrib.framework.nest

tf.compat.v1.enable_v2_behavior()

np.random.seed(0)

# Test the TFF is working:
tff.federated_computation(lambda: 'Hello, World!')()
# Out:
# 'Hello, World!'

# %%
# A fixed vocabularly of ASCII chars that occur in the works of Shakespeare and Dickens:
vocab = list('dhlptx@DHLPTX $(,048cgkoswCGKOSW[_#\'/37;?bfjnrvzBFJNRVZ"&*.26:\naeimquyAEIMQUY]!%)-159\r')

# Creating a mapping from unique characters to indices
char2idx = {u:i for i, u in enumerate(vocab)}
idx2char = np.array(vocab)

# %%
def load_model(batch_size):
    urls = {
      1: 'https://storage.googleapis.com/tff-models-public/dickens_rnn.batch1.kerasmodel',
      8: 'https://storage.googleapis.com/tff-models-public/dickens_rnn.batch8.kerasmodel'}
    assert batch_size in urls, 'batch_size must be in ' + str(urls.keys())
    url = urls[batch_size]
    local_file = tf.keras.utils.get_file(os.path.basename(url), origin=url)  
    return tf.keras.models.load_model(local_file, compile=False)

# %%
def generate_text(model, start_string):
    num_generate = 200
    input_eval = [char2idx[s] for s in start_string]
    input_eval = tf.expand_dims(input_eval, 0)
    text_generated = []
    temperature = 1.0

    model.reset_states()
    for i in range(num_generate):
        predictions = model(input_eval)
        predictions = tf.squeeze(predictions, 0)
        predictions = predictions / temperature
        predicted_id = tf.multinomial(predictions, num_samples=1)[-1,0].numpy()      
        input_eval = tf.expand_dims([predicted_id], 0)      
        text_generated.append(idx2char[predicted_id])

    return (start_string + ''.join(text_generated))

# %%
# Text generation requires a batch_size=1 model.
keras_model_batch1 = load_model(batch_size=1)
# print(generate_text(keras_model_batch1, 'What of TensorFlow Federated, you ask? '))
keras_model_batch1.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_6 (Embedding)      (1, None, 256)            22016
# _________________________________________________________________
# gru_6 (GRU)                  (1, None, 1024)           3935232
# _________________________________________________________________
# dense_6 (Dense)              (1, None, 86)             88150
# =================================================================
# Total params: 4,045,398
# Trainable params: 4,045,398
# Non-trainable params: 0
# _________________________________________________________________

# %%
train_data, test_data = tff.simulation.datasets.shakespeare.load_data()
train_data.client_ids
# Out:
# ['ALL_S_WELL_THAT_ENDS_WELL_ADAM',
#  'ALL_S_WELL_THAT_ENDS_WELL_AEDILE',
#  'ALL_S_WELL_THAT_ENDS_WELL_AGRIPPA',
#  'ALL_S_WELL_THAT_ENDS_WELL_ALEXAS',
#  'ALL_S_WELL_THAT_ENDS_WELL_ALL',
#  'ALL_S_WELL_THAT_ENDS_WELL_ALL_THE_PEOPLE',
#  'ALL_S_WELL_THAT_ENDS_WELL_AMIENS',
#  'ALL_S_WELL_THAT_ENDS_WELL_ANTIPHOLUS_OF_EPHESUS',
#  'ALL_S_WELL_THAT_ENDS_WELL_ANTONY',
#  'ALL_S_WELL_THAT_ENDS_WELL_ARVIRAGUS',
#  'ALL_S_WELL_THAT_ENDS_WELL_AUDREY',
#  'ALL_S_WELL_THAT_ENDS_WELL_AUFIDIUS',
#  'ALL_S_WELL_THAT_ENDS_WELL_BELARIUS',
#  'ALL_S_WELL_THAT_ENDS_WELL_BOTH',
#  'ALL_S_WELL_THAT_ENDS_WELL_BOTH_TRIBUNES',
#  'ALL_S_WELL_THAT_ENDS_WELL_BROTHERS',
#  'ALL_S_WELL_THAT_ENDS_WELL_BRUTUS',
#  'ALL_S_WELL_THAT_ENDS_WELL_CAESAR',
#  'ALL_S_WELL_THAT_ENDS_WELL_CANIDIUS',
#  'ALL_S_WELL_THAT_ENDS_WELL_CAPTAIN',
#  'ALL_S_WELL_THAT_ENDS_WELL_CELIA',
#  'ALL_S_WELL_THAT_ENDS_WELL_CENTURION',
#  'ALL_S_WELL_THAT_ENDS_WELL_CHARLES',
#  'ALL_S_WELL_THAT_ENDS_WELL_CHARMIAN',
#  'ALL_S_WELL_THAT_ENDS_WELL_CITIZEN',
#  'ALL_S_WELL_THAT_ENDS_WELL_CITIZENS',
#  'ALL_S_WELL_THAT_ENDS_WELL_CLEOPATRA',
#  'ALL_S_WELL_THAT_ENDS_WELL_CLOTEN',
#  'ALL_S_WELL_THAT_ENDS_WELL_CLOWN',
#  'ALL_S_WELL_THAT_ENDS_WELL_COMINIUS',
#  'ALL_S_WELL_THAT_ENDS_WELL_CONSPIRATORS',
#  'ALL_S_WELL_THAT_ENDS_WELL_CORIN',
#  'ALL_S_WELL_THAT_ENDS_WELL_CORIOLANUS',
#  'ALL_S_WELL_THAT_ENDS_WELL_CORNELIUS',
#  'ALL_S_WELL_THAT_ENDS_WELL_CYMBELINE',
#  'ALL_S_WELL_THAT_ENDS_WELL_DEMETRIUS',
#  'ALL_S_WELL_THAT_ENDS_WELL_DENNIS',
#  'ALL_S_WELL_THAT_ENDS_WELL_DERCETAS',
#  'ALL_S_WELL_THAT_ENDS_WELL_DID_CALL_ME_BROTHER',
#  'ALL_S_WELL_THAT_ENDS_WELL_DIOMEDES',
#  'ALL_S_WELL_THAT_ENDS_WELL_DOLABELLA',
#  'ALL_S_WELL_THAT_ENDS_WELL_DOTH_FOR_A_WIFE_ABHOR',
#  'ALL_S_WELL_THAT_ENDS_WELL_DROMIO_OF_EPHESUS',
#  'ALL_S_WELL_THAT_ENDS_WELL_DUKE_SENIOR',
#  'ALL_S_WELL_THAT_ENDS_WELL_EGYPTIAN',
#  'ALL_S_WELL_THAT_ENDS_WELL_ENOBARBUS',
#  'ALL_S_WELL_THAT_ENDS_WELL_EROS',
#  'ALL_S_WELL_THAT_ENDS_WELL_EUPHRONIUS',
#  'ALL_S_WELL_THAT_ENDS_WELL_FIRST_BROTHER',
#  'ALL_S_WELL_THAT_ENDS_WELL_FIRST_CAPTAIN',
#  'ALL_S_WELL_THAT_ENDS_WELL_FIRST_CITIZEN',
#  'ALL_S_WELL_THAT_ENDS_WELL_FIRST_CONSPIRATOR',
#  'ALL_S_WELL_THAT_ENDS_WELL_FIRST_GAOLER',
#  'ALL_S_WELL_THAT_ENDS_WELL_FIRST_GENTLEMAN',
#  'ALL_S_WELL_THAT_ENDS_WELL_FIRST_GUARD',
#  'ALL_S_WELL_THAT_ENDS_WELL_FIRST_LORD',
#  'ALL_S_WELL_THAT_ENDS_WELL_FIRST_OFFICER',
#  'ALL_S_WELL_THAT_ENDS_WELL_FIRST_PAGE',
#  'ALL_S_WELL_THAT_ENDS_WELL_FIRST_SENATOR',
#  'ALL_S_WELL_THAT_ENDS_WELL_FIRST_SERVANT',
#  'ALL_S_WELL_THAT_ENDS_WELL_FIRST_SOLDIER',
#  'ALL_S_WELL_THAT_ENDS_WELL_FIRST_WATCH',
#  'ALL_S_WELL_THAT_ENDS_WELL_FOURTH_CITIZEN',
#  'ALL_S_WELL_THAT_ENDS_WELL_FREDERICK',
#  'ALL_S_WELL_THAT_ENDS_WELL_FRENCHMAN',
#  'ALL_S_WELL_THAT_ENDS_WELL_GALLUS',
#  'ALL_S_WELL_THAT_ENDS_WELL_GAOLER',
#  'ALL_S_WELL_THAT_ENDS_WELL_GUARDSMAN',
#  'ALL_S_WELL_THAT_ENDS_WELL_GUIDERIUS',
#  'ALL_S_WELL_THAT_ENDS_WELL_GUIDERIUS_AND_ARVIRAGUS',
#  'ALL_S_WELL_THAT_ENDS_WELL_HERALD',
#  'ALL_S_WELL_THAT_ENDS_WELL_HYMEN',
#  'ALL_S_WELL_THAT_ENDS_WELL_IACHIMO',
#  'ALL_S_WELL_THAT_ENDS_WELL_IMOGEN',
#  'ALL_S_WELL_THAT_ENDS_WELL_IRAS',
#  'ALL_S_WELL_THAT_ENDS_WELL_JAQUES',
#  'ALL_S_WELL_THAT_ENDS_WELL_JAQUES_DE_BOYS',
#  'ALL_S_WELL_THAT_ENDS_WELL_JUPITER',
#  'ALL_S_WELL_THAT_ENDS_WELL_LADY',
#  'ALL_S_WELL_THAT_ENDS_WELL_LARTIUS',
#  'ALL_S_WELL_THAT_ENDS_WELL_LEPIDUS',
#  'ALL_S_WELL_THAT_ENDS_WELL_LE_BEAU',
#  'ALL_S_WELL_THAT_ENDS_WELL_LIEUTENANT',
#  'ALL_S_WELL_THAT_ENDS_WELL_LORD',
#  'ALL_S_WELL_THAT_ENDS_WELL_LOVE',
#  'ALL_S_WELL_THAT_ENDS_WELL_LUCIUS',
#  'ALL_S_WELL_THAT_ENDS_WELL_MAECENAS',
#  'ALL_S_WELL_THAT_ENDS_WELL_MARCIUS',
#  'ALL_S_WELL_THAT_ENDS_WELL_MARDIAN',
#  'ALL_S_WELL_THAT_ENDS_WELL_MARTEXT',
#  'ALL_S_WELL_THAT_ENDS_WELL_MENAS',
#  'ALL_S_WELL_THAT_ENDS_WELL_MENECRATES',
#  'ALL_S_WELL_THAT_ENDS_WELL_MENENIUS',
#  'ALL_S_WELL_THAT_ENDS_WELL_MESSENGER',
#  'ALL_S_WELL_THAT_ENDS_WELL_MOTHER',
#  'ALL_S_WELL_THAT_ENDS_WELL_OCTAVIA',
#  'ALL_S_WELL_THAT_ENDS_WELL_OF_EPHESUS',
#  'ALL_S_WELL_THAT_ENDS_WELL_OLIVER',
#  'ALL_S_WELL_THAT_ENDS_WELL_ORLANDO',
#  'ALL_S_WELL_THAT_ENDS_WELL_PATRICIANS',
#  'ALL_S_WELL_THAT_ENDS_WELL_PHEBE',
#  'ALL_S_WELL_THAT_ENDS_WELL_PHILARIO',
#  'ALL_S_WELL_THAT_ENDS_WELL_PHILO',
#  'ALL_S_WELL_THAT_ENDS_WELL_PISANIO',
#  'ALL_S_WELL_THAT_ENDS_WELL_PLEBEIANS',
#  'ALL_S_WELL_THAT_ENDS_WELL_POMPEY',
#  'ALL_S_WELL_THAT_ENDS_WELL_POSTHUMUS',
#  'ALL_S_WELL_THAT_ENDS_WELL_PROCULEIUS',
#  'ALL_S_WELL_THAT_ENDS_WELL_QUEEN',
#  'ALL_S_WELL_THAT_ENDS_WELL_ROMAN',
#  'ALL_S_WELL_THAT_ENDS_WELL_ROSALIND',
#  'ALL_S_WELL_THAT_ENDS_WELL_SCARUS',
#  'ALL_S_WELL_THAT_ENDS_WELL_SECOND_BROTHER',
#  'ALL_S_WELL_THAT_ENDS_WELL_SECOND_CAPTAIN',
#  'ALL_S_WELL_THAT_ENDS_WELL_SECOND_CITIZEN',
#  'ALL_S_WELL_THAT_ENDS_WELL_SECOND_CONSPIRATOR',
#  'ALL_S_WELL_THAT_ENDS_WELL_SECOND_GENTLEMAN',
#  'ALL_S_WELL_THAT_ENDS_WELL_SECOND_GUARD',
#  'ALL_S_WELL_THAT_ENDS_WELL_SECOND_LORD',
#  'ALL_S_WELL_THAT_ENDS_WELL_SECOND_MESSENGER',
#  'ALL_S_WELL_THAT_ENDS_WELL_SECOND_OFFICER',
#  'ALL_S_WELL_THAT_ENDS_WELL_SECOND_PAGE',
#  'ALL_S_WELL_THAT_ENDS_WELL_SECOND_SENATOR',
#  'ALL_S_WELL_THAT_ENDS_WELL_SECOND_SERVANT',
#  'ALL_S_WELL_THAT_ENDS_WELL_SECOND_SOLDIER',
#  'ALL_S_WELL_THAT_ENDS_WELL_SECOND_WATCH',
#  'ALL_S_WELL_THAT_ENDS_WELL_SELEUCUS',
#  'ALL_S_WELL_THAT_ENDS_WELL_SENATORS',
#  'ALL_S_WELL_THAT_ENDS_WELL_SEVENTH_CITIZEN',
#  'ALL_S_WELL_THAT_ENDS_WELL_SICILIUS',
#  'ALL_S_WELL_THAT_ENDS_WELL_SICINIUS',
#  'ALL_S_WELL_THAT_ENDS_WELL_SILIUS',
#  'ALL_S_WELL_THAT_ENDS_WELL_SILVIUS',
#  'ALL_S_WELL_THAT_ENDS_WELL_SOLDIER',
#  'ALL_S_WELL_THAT_ENDS_WELL_SOLDIERS',
#  'ALL_S_WELL_THAT_ENDS_WELL_SOOTHSAYER',
#  'ALL_S_WELL_THAT_ENDS_WELL_THIRD_CITIZEN',
#  'ALL_S_WELL_THAT_ENDS_WELL_THIRD_CONSPIRATOR',
#  'ALL_S_WELL_THAT_ENDS_WELL_THIRD_ROMAN',
#  'ALL_S_WELL_THAT_ENDS_WELL_THIRD_SERVANT',
#  'ALL_S_WELL_THAT_ENDS_WELL_THIRD_SOLDIER',
#  'ALL_S_WELL_THAT_ENDS_WELL_THIS_IS_THE_FAIRY_LAND',
#  'ALL_S_WELL_THAT_ENDS_WELL_THYREUS',
#  'ALL_S_WELL_THAT_ENDS_WELL_TOUCHSTONE',
#  'ALL_S_WELL_THAT_ENDS_WELL_TRIBUNE',
#  'ALL_S_WELL_THAT_ENDS_WELL_VALERIA',
#  'ALL_S_WELL_THAT_ENDS_WELL_VARRIUS',
#  'ALL_S_WELL_THAT_ENDS_WELL_VENTIDIUS',
#  'ALL_S_WELL_THAT_ENDS_WELL_VIRGILIA',
#  'ALL_S_WELL_THAT_ENDS_WELL_VOLSCE',
#  'ALL_S_WELL_THAT_ENDS_WELL_VOLUMNIA',
#  'ALL_S_WELL_THAT_ENDS_WELL_WILLIAM',
#  'MUCH_ADO_ABOUT_NOTHING_BIANCA',
#  'MUCH_ADO_ABOUT_NOTHING_BRABANTIO',
#  'MUCH_ADO_ABOUT_NOTHING_CASSIO',
#  'MUCH_ADO_ABOUT_NOTHING_CLOWN',
#  'MUCH_ADO_ABOUT_NOTHING_DESDEMONA',
#  'MUCH_ADO_ABOUT_NOTHING_DUKE',
#  'MUCH_ADO_ABOUT_NOTHING_EMILIA',
#  'MUCH_ADO_ABOUT_NOTHING_FIRST_GENTLEMAN',
#  'MUCH_ADO_ABOUT_NOTHING_FIRST_MUSICIAN',
#  'MUCH_ADO_ABOUT_NOTHING_FIRST_OFFICER',
#  'MUCH_ADO_ABOUT_NOTHING_FIRST_SENATOR',
#  'MUCH_ADO_ABOUT_NOTHING_FOURTH_GENTLEMAN',
#  'MUCH_ADO_ABOUT_NOTHING_GRATIANO',
#  'MUCH_ADO_ABOUT_NOTHING_IAGO',
#  'MUCH_ADO_ABOUT_NOTHING_LODOVICO',
#  'MUCH_ADO_ABOUT_NOTHING_MESSENGER',
#  'MUCH_ADO_ABOUT_NOTHING_MONTANO',
#  'MUCH_ADO_ABOUT_NOTHING_OTHELLO',
#  'MUCH_ADO_ABOUT_NOTHING_RODERIGO',
#  'MUCH_ADO_ABOUT_NOTHING_SAILOR',
#  'MUCH_ADO_ABOUT_NOTHING_SECOND_GENTLEMAN',
#  'MUCH_ADO_ABOUT_NOTHING_SECOND_SENATOR',
#  'MUCH_ADO_ABOUT_NOTHING_THIRD_GENTLEMAN',
#  'PERICLES__PRINCE_OF_TYRE_ABBOT',
#  'PERICLES__PRINCE_OF_TYRE_ALL',
#  'PERICLES__PRINCE_OF_TYRE_ANNE',
#  'PERICLES__PRINCE_OF_TYRE_ANOTHER_LORD',
#  'PERICLES__PRINCE_OF_TYRE_ARCHBISHOP',
#  'PERICLES__PRINCE_OF_TYRE_AUMERLE',
#  'PERICLES__PRINCE_OF_TYRE_BAGOT',
#  'PERICLES__PRINCE_OF_TYRE_BERKELEY',
#  'PERICLES__PRINCE_OF_TYRE_BISHOP_OF_ELY',
#  'PERICLES__PRINCE_OF_TYRE_BLUNT',
#  'PERICLES__PRINCE_OF_TYRE_BOLINGBROKE',
#  'PERICLES__PRINCE_OF_TYRE_BRAKENBURY',
#  'PERICLES__PRINCE_OF_TYRE_BUCKINGHAM',
#  'PERICLES__PRINCE_OF_TYRE_BUSHY',
#  'PERICLES__PRINCE_OF_TYRE_CAPTAIN',
#  'PERICLES__PRINCE_OF_TYRE_CARDINAL',
#  'PERICLES__PRINCE_OF_TYRE_CARLISLE',
#  'PERICLES__PRINCE_OF_TYRE_CATESBY',
#  'PERICLES__PRINCE_OF_TYRE_CHILDREN',
#  'PERICLES__PRINCE_OF_TYRE_CHRISTOPHER',
#  'PERICLES__PRINCE_OF_TYRE_CLARENCE',
#  'PERICLES__PRINCE_OF_TYRE_DAUGHTER',
#  'PERICLES__PRINCE_OF_TYRE_DERBY',
#  'PERICLES__PRINCE_OF_TYRE_DORSET',
#  'PERICLES__PRINCE_OF_TYRE_DUCHESS',
#  'PERICLES__PRINCE_OF_TYRE_EXTON',
#  'PERICLES__PRINCE_OF_TYRE_FIRST_CITIZEN',
#  'PERICLES__PRINCE_OF_TYRE_FIRST_HERALD',
#  'PERICLES__PRINCE_OF_TYRE_FIRST_MURDERER',
#  'PERICLES__PRINCE_OF_TYRE_FITZWATER',
#  'PERICLES__PRINCE_OF_TYRE_FOURTH_MESSENGER',
#  'PERICLES__PRINCE_OF_TYRE_GARDENER',
#  'PERICLES__PRINCE_OF_TYRE_GAUNT',
#  'PERICLES__PRINCE_OF_TYRE_GHOST',
#  'PERICLES__PRINCE_OF_TYRE_GHOSTS',
#  'PERICLES__PRINCE_OF_TYRE_GHOST_OF_RIVERS',
#  'PERICLES__PRINCE_OF_TYRE_GHOST_OF_VAUGHAN',
#  'PERICLES__PRINCE_OF_TYRE_GLOUCESTER',
#  'PERICLES__PRINCE_OF_TYRE_GREEN',
#  'PERICLES__PRINCE_OF_TYRE_GREY',
#  'PERICLES__PRINCE_OF_TYRE_GROOM',
#  'PERICLES__PRINCE_OF_TYRE_HASTINGS',
#  'PERICLES__PRINCE_OF_TYRE_KEEPER',
#  'PERICLES__PRINCE_OF_TYRE_KING_EDWARD',
#  'PERICLES__PRINCE_OF_TYRE_KING_RICHARD',
#  'PERICLES__PRINCE_OF_TYRE_LADY',
#  'PERICLES__PRINCE_OF_TYRE_LOVEL',
#  'PERICLES__PRINCE_OF_TYRE_MARSHAL',
#  'PERICLES__PRINCE_OF_TYRE_MAYOR',
#  'PERICLES__PRINCE_OF_TYRE_MESSENGER',
#  'PERICLES__PRINCE_OF_TYRE_MOWBRAY',
#  'PERICLES__PRINCE_OF_TYRE_NORFOLK',
#  'PERICLES__PRINCE_OF_TYRE_NORTHUMBERLAND',
#  'PERICLES__PRINCE_OF_TYRE_OXFORD',
#  'PERICLES__PRINCE_OF_TYRE_PAGE',
#  'PERICLES__PRINCE_OF_TYRE_PERCY',
#  'PERICLES__PRINCE_OF_TYRE_PRIEST',
#  'PERICLES__PRINCE_OF_TYRE_PRINCE',
#  'PERICLES__PRINCE_OF_TYRE_PURSUIVANT',
#  'PERICLES__PRINCE_OF_TYRE_QUEEN',
#  'PERICLES__PRINCE_OF_TYRE_QUEEN_ELIZABETH',
#  'PERICLES__PRINCE_OF_TYRE_QUEEN_MARGARET',
#  'PERICLES__PRINCE_OF_TYRE_RATCLIFF',
#  'PERICLES__PRINCE_OF_TYRE_RICHMOND',
#  'PERICLES__PRINCE_OF_TYRE_RIVERS',
#  'PERICLES__PRINCE_OF_TYRE_ROSS',
#  'PERICLES__PRINCE_OF_TYRE_SALISBURY',
#  'PERICLES__PRINCE_OF_TYRE_SCRIVENER',
#  'PERICLES__PRINCE_OF_TYRE_SCROOP',
#  'PERICLES__PRINCE_OF_TYRE_SECOND_CITIZEN',
#  'PERICLES__PRINCE_OF_TYRE_SECOND_HERALD',
#  'PERICLES__PRINCE_OF_TYRE_SECOND_MESSENGER',
#  'PERICLES__PRINCE_OF_TYRE_SECOND_MURDERER',
#  'PERICLES__PRINCE_OF_TYRE_SERVANT',
#  'PERICLES__PRINCE_OF_TYRE_SERVINGMAN',
#  'PERICLES__PRINCE_OF_TYRE_SON',
#  'PERICLES__PRINCE_OF_TYRE_STANLEY',
#  'PERICLES__PRINCE_OF_TYRE_SURREY',
#  'PERICLES__PRINCE_OF_TYRE_THIRD_CITIZEN',
#  'PERICLES__PRINCE_OF_TYRE_THIRD_MESSENGER',
#  'PERICLES__PRINCE_OF_TYRE_TYRREL',
#  'PERICLES__PRINCE_OF_TYRE_WILLOUGHBY',
#  'PERICLES__PRINCE_OF_TYRE_YORK',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_ABERGAVENNY',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_ALENCON',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_ALICE',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_ALL',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_AMBASSADOR',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_ANNE',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_ARCHBISHOP',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_ARTHUR',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_AUSTRIA',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_BARDOLPH',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_BASSET',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_BASTARD',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_BATES',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_BEDFORD',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_BIGOT',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_BLANCH',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_BOLINGBROKE',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_BONA',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_BOTH',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_BOURBON',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_BOY',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_BRANDON',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_BRITAINE',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_BUCKINGHAM',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_BULLCALF',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_BURGUNDY',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_BUTTS',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_CADE',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_CAMBRIDGE',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_CAMPEIUS',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_CANTERBURY',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_CAPTAIN',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_CAPUCIUS',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_CARDINAL',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_CHAMBERLAIN',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_CHANCELLOR',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_CHARLES',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_CHATILLON',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_CHIEF_JUSTICE',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_CHORUS',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_CITIZEN',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_CLARENCE',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_CLERK',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_CLIFFORD',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_COLVILLE',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_COMMONS',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_CONSTABLE',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_CONSTANCE',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_COUNTESS',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_CRANMER',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_CRIER',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_CROMWELL',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_DAUPHIN',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_DAVY',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_DENNY',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_DICK',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_DOLL',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_DUCHESS',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_EDWARD',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_ELINOR',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_ELY',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_ENGLISH_HERALD',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_ERPINGHAM',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_ESSEX',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_EXECUTIONER',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_EXETER',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_FALSTAFF',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_FANG',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_FASTOLFE',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_FATHER',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_FEEBLE',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_FIRST_BEADLE',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_FIRST_CITIZEN',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_FIRST_GENTLEMAN',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_FIRST_KEEPER',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_FIRST_MURDERER',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_FIRST_NEIGHBOUR',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_FIRST_PETITIONER',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_FIRST_SENTINEL',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_FIRST_SOLDIER',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_FIRST_WARDER',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_FIRST_WATCHMAN',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_FLUELLEN',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_FRANCIS',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_FRENCH_HERALD',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_FRENCH_KING',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_FRENCH_SOLDIER',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_GARDINER',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_GARGRAVE',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_GARTER',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_GENERAL_OF_THE_FRENCH',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_GENTLEMAN',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_GEORGE',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_GLOUCESTER',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_GOVERNOR',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_GOWER',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_GRANDPRE',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_GREY',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_GRIFFITH',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_GUILDFORD',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_HARCOURT',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_HASTINGS',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_HERALD',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_HORNER',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_HOSTESS',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_HUBERT',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_HUME',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_HUNTSMAN',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_IDEN',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_JAMY',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_JOHN',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_JUSTICE',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_KATHARINE',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_KATHERINE',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_KEEPER',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_KING',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_KING_EDWARD',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_KING_HENRY',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_KING_JOHN',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_KING_PHILIP',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_LADY_FAULCONBRIDGE',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_LADY_GREY',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_LADY_NORTHUMBERLAND',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_LADY_PERCY',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_LAWYER',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_LEWIS',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_LIEUTENANT',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_LINCOLN',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_LORD_BARDOLPH',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_LOVELL',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_LUCY',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_MACMORRIS',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_MAN',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_MARGARET',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_MARGERY_JOURDAIN',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_MAYOR',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_MELUN',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_MESSENGER',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_MICHAEL',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_MONTAGUE',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_MONTGOMERY',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_MONTJOY',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_MORTIMER',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_MORTON',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_MOULDY',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_MOWBRAY',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_NOBLEMAN',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_NORFOLK',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_NORTHUMBERLAND',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_NYM',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_OFFICER',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_OLD_LADY',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_ORLEANS',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_OXFORD',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_PAGE',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_PANDULPH',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_PATIENCE',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_PEMBROKE',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_PETER',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_PETO',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_PISTOL',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_PLANTAGENET',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_POINS',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_PORTER',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_POST',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_PRINCE',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_PRINCE_HENRY',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_PRINCE_HUMPHREY',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_PRINCE_JOHN',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_PRINCE_OF_WALES',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_PUCELLE',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_QUEEN',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_QUEEN_ELIZABETH',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_QUEEN_ISABEL',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_QUEEN_KATHARINE',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_QUEEN_MARGARET',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_RAMBURES',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_REIGN',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_REIGNIER',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_RICHARD',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_RIVERS',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_ROBERT',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_RUMOUR',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_RUTLAND',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_SALISBURY',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_SANDYS',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_SAY',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_SCALES',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_SCOUT',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_SCRIBE',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_SCROOP',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_SECOND_DRAWER',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_SECOND_GENTLEMAN',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_SECOND_KEEPER',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_SECOND_MESSENGER',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_SECOND_MURDERER',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_SECOND_PETITIONER',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_SECOND_WATCHMAN',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_SERGEANT',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_SERVANT',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_SHALLOW',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_SHEPHERD',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_SHERIFF',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_SILENCE',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_SIMPCOX',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_SMITH',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_SOLDIER',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_SOMERSET',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_SOMERVILLE',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_SON',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_SPIRIT',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_STAFFORD',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_STANLEY',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_SUFFOLK',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_SURREY',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_SURVEYOR',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_TALBOT',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_THIRD_DRAWER',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_THIRD_GENTLEMAN',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_THIRD_GROOM',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_THIRD_MESSENGER',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_THIRD_WATCHMAN',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_TOWNSMAN',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_TRAVERS',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_TUTOR',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_VAUX',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_VERNON',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_WARWICK',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_WESTMORELAND',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_WHITMORE',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_WIFE',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_WILLIAMS',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_WILLIAM_STAFFORD',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_WINCHESTER',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_WOLSEY',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_WOODVILLE',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_YORK',
#  'THE_FIRST_PART_OF_KING_HENRY_THE_FOURTH_YOUNG_CLIFFORD',
#  'THE_TAMING_OF_THE_SHREW_ADRIAN',
#  'THE_TAMING_OF_THE_SHREW_ALCIBIADES',
#  'THE_TAMING_OF_THE_SHREW_ALL_SERVANTS',
#  'THE_TAMING_OF_THE_SHREW_ALONSO',
#  'THE_TAMING_OF_THE_SHREW_ANTONIO',
#  'THE_TAMING_OF_THE_SHREW_APEMANTUS',
#  'THE_TAMING_OF_THE_SHREW_ARIEL',
#  'THE_TAMING_OF_THE_SHREW_BANDITTI',
#  'THE_TAMING_OF_THE_SHREW_BASSIANUS',
#  'THE_TAMING_OF_THE_SHREW_BOATSWAIN',
#  'THE_TAMING_OF_THE_SHREW_BOTH',
#  'THE_TAMING_OF_THE_SHREW_CALIBAN',
#  'THE_TAMING_OF_THE_SHREW_CAPHIS',
#  'THE_TAMING_OF_THE_SHREW_CAPTAIN',
#  'THE_TAMING_OF_THE_SHREW_CERES',
#  'THE_TAMING_OF_THE_SHREW_CUPID',
#  'THE_TAMING_OF_THE_SHREW_FERDINAND',
#  'THE_TAMING_OF_THE_SHREW_FIRST_BANDIT',
#  'THE_TAMING_OF_THE_SHREW_FIRST_LORD',
#  'THE_TAMING_OF_THE_SHREW_FIRST_SENATOR',
#  'THE_TAMING_OF_THE_SHREW_FIRST_SERVANT',
#  'THE_TAMING_OF_THE_SHREW_FIRST_STRANGER',
#  'THE_TAMING_OF_THE_SHREW_FLAMINIUS',
#  'THE_TAMING_OF_THE_SHREW_FLAVIUS',
#  'THE_TAMING_OF_THE_SHREW_FOOL',
#  'THE_TAMING_OF_THE_SHREW_FOURTH_LORD',
#  'THE_TAMING_OF_THE_SHREW_FRANCISCO',
#  'THE_TAMING_OF_THE_SHREW_GONZALO',
#  'THE_TAMING_OF_THE_SHREW_HORTENSIUS',
#  'THE_TAMING_OF_THE_SHREW_IRIS',
#  'THE_TAMING_OF_THE_SHREW_JEWELLER',
#  'THE_TAMING_OF_THE_SHREW_JUNO',
#  'THE_TAMING_OF_THE_SHREW_LUCILIUS',
#  'THE_TAMING_OF_THE_SHREW_LUCIUS',
#  'THE_TAMING_OF_THE_SHREW_LUCULLIUS',
#  'THE_TAMING_OF_THE_SHREW_LUCULLUS',
#  'THE_TAMING_OF_THE_SHREW_MARCUS',
#  'THE_TAMING_OF_THE_SHREW_MASTER',
#  'THE_TAMING_OF_THE_SHREW_MERCHANT',
#  'THE_TAMING_OF_THE_SHREW_MESSENGER',
#  'THE_TAMING_OF_THE_SHREW_MIRANDA',
#  'THE_TAMING_OF_THE_SHREW_OLD_ATHENIAN',
#  'THE_TAMING_OF_THE_SHREW_PAGE',
#  'THE_TAMING_OF_THE_SHREW_PAINTER',
#  'THE_TAMING_OF_THE_SHREW_PHILOTUS',
#  'THE_TAMING_OF_THE_SHREW_PHRYNIA_AND_TIMANDRA',
#  'THE_TAMING_OF_THE_SHREW_POET',
#  'THE_TAMING_OF_THE_SHREW_PROSPERO',
#  'THE_TAMING_OF_THE_SHREW_SATURNINUS',
#  'THE_TAMING_OF_THE_SHREW_SEBASTIAN',
#  'THE_TAMING_OF_THE_SHREW_SECOND_BANDIT',
#  'THE_TAMING_OF_THE_SHREW_SECOND_LORD',
#  'THE_TAMING_OF_THE_SHREW_SECOND_SENATOR',
#  'THE_TAMING_OF_THE_SHREW_SECOND_SERVANT',
#  'THE_TAMING_OF_THE_SHREW_SECOND_STRANGER',
#  'THE_TAMING_OF_THE_SHREW_SEMPRONIUS',
#  'THE_TAMING_OF_THE_SHREW_SENATOR',
#  'THE_TAMING_OF_THE_SHREW_SERVANT',
#  'THE_TAMING_OF_THE_SHREW_SERVILIUS',
#  'THE_TAMING_OF_THE_SHREW_SOLDIER',
#  'THE_TAMING_OF_THE_SHREW_STEPHANO',
#  'THE_TAMING_OF_THE_SHREW_TAKE_IN_THE_TOPSAIL',
#  'THE_TAMING_OF_THE_SHREW_TAMORA',
#  'THE_TAMING_OF_THE_SHREW_THIRD_BANDIT',
#  'THE_TAMING_OF_THE_SHREW_THIRD_LORD',
#  'THE_TAMING_OF_THE_SHREW_THIRD_SENATOR',
#  'THE_TAMING_OF_THE_SHREW_THIRD_SERVANT',
#  'THE_TAMING_OF_THE_SHREW_TIMANDRA',
#  'THE_TAMING_OF_THE_SHREW_TIMON',
#  'THE_TAMING_OF_THE_SHREW_TITUS',
#  'THE_TAMING_OF_THE_SHREW_TRINCULO',
#  'THE_TAMING_OF_THE_SHREW_VENTIDIUS',
#  'THE_TRAGEDY_OF_KING_LEAR_ABHORSON',
#  'THE_TRAGEDY_OF_KING_LEAR_ALL',
#  'THE_TRAGEDY_OF_KING_LEAR_ANGELO',
#  'THE_TRAGEDY_OF_KING_LEAR_ANGUS',
#  'THE_TRAGEDY_OF_KING_LEAR_ANNE',
#  'THE_TRAGEDY_OF_KING_LEAR_ANTONIO',
#  'THE_TRAGEDY_OF_KING_LEAR_ARMADO',
#  'THE_TRAGEDY_OF_KING_LEAR_ARRAGON',
#  'THE_TRAGEDY_OF_KING_LEAR_BANQUO',
#  'THE_TRAGEDY_OF_KING_LEAR_BARDOLPH',
#  'THE_TRAGEDY_OF_KING_LEAR_BARNARDINE',
#  'THE_TRAGEDY_OF_KING_LEAR_BASSANIO',
#  'THE_TRAGEDY_OF_KING_LEAR_BEROWNE',
#  'THE_TRAGEDY_OF_KING_LEAR_BOTTOM',
#  'THE_TRAGEDY_OF_KING_LEAR_BOYET',
#  'THE_TRAGEDY_OF_KING_LEAR_CAITHNESS',
#  'THE_TRAGEDY_OF_KING_LEAR_CAIUS',
#  'THE_TRAGEDY_OF_KING_LEAR_CHORUS',
#  'THE_TRAGEDY_OF_KING_LEAR_CLAUDIO',
#  'THE_TRAGEDY_OF_KING_LEAR_CLERK',
#  'THE_TRAGEDY_OF_KING_LEAR_COSTARD',
#  'THE_TRAGEDY_OF_KING_LEAR_DEMETRIUS',
#  'THE_TRAGEDY_OF_KING_LEAR_DESERVING_A_FAIR_LADY',
#  'THE_TRAGEDY_OF_KING_LEAR_DOCTOR',
#  'THE_TRAGEDY_OF_KING_LEAR_DONALBAIN',
#  'THE_TRAGEDY_OF_KING_LEAR_DUKE',
#  'THE_TRAGEDY_OF_KING_LEAR_DUKE_OF_VENICE',
#  'THE_TRAGEDY_OF_KING_LEAR_DULL',
#  'THE_TRAGEDY_OF_KING_LEAR_DUMAIN',
#  'THE_TRAGEDY_OF_KING_LEAR_DUNCAN',
#  'THE_TRAGEDY_OF_KING_LEAR_EGEUS',
#  'THE_TRAGEDY_OF_KING_LEAR_ELBOW',
#  'THE_TRAGEDY_OF_KING_LEAR_ESCALUS',
#  'THE_TRAGEDY_OF_KING_LEAR_EVANS',
#  'THE_TRAGEDY_OF_KING_LEAR_FAIRY',
#  'THE_TRAGEDY_OF_KING_LEAR_FAIRY_QUEEN',
#  'THE_TRAGEDY_OF_KING_LEAR_FALSTAFF',
#  'THE_TRAGEDY_OF_KING_LEAR_FENTON',
#  'THE_TRAGEDY_OF_KING_LEAR_FIRST_APPARITION',
#  'THE_TRAGEDY_OF_KING_LEAR_FIRST_FAIRY',
#  'THE_TRAGEDY_OF_KING_LEAR_FIRST_GENTLEMAN',
#  'THE_TRAGEDY_OF_KING_LEAR_FIRST_MURTHERER',
#  'THE_TRAGEDY_OF_KING_LEAR_FIRST_SERVANT',
#  'THE_TRAGEDY_OF_KING_LEAR_FIRST_WITCH',
#  'THE_TRAGEDY_OF_KING_LEAR_FLUTE',
#  'THE_TRAGEDY_OF_KING_LEAR_FORD',
#  'THE_TRAGEDY_OF_KING_LEAR_FORESTER',
#  'THE_TRAGEDY_OF_KING_LEAR_FRANCISCA',
#  'THE_TRAGEDY_OF_KING_LEAR_FRIAR',
#  'THE_TRAGEDY_OF_KING_LEAR_FROTH',
#  'THE_TRAGEDY_OF_KING_LEAR_GENTLEWOMAN',
#  'THE_TRAGEDY_OF_KING_LEAR_GOBBO',
#  'THE_TRAGEDY_OF_KING_LEAR_GRATIANO',
#  'THE_TRAGEDY_OF_KING_LEAR_HECATE',
#  'THE_TRAGEDY_OF_KING_LEAR_HELENA',
#  'THE_TRAGEDY_OF_KING_LEAR_HERMIA',
#  'THE_TRAGEDY_OF_KING_LEAR_HIPPOLYTA',
#  'THE_TRAGEDY_OF_KING_LEAR_HOLOFERNES',
#  'THE_TRAGEDY_OF_KING_LEAR_HOST',
#  'THE_TRAGEDY_OF_KING_LEAR_ISABELLA',
#  'THE_TRAGEDY_OF_KING_LEAR_JAQUENETTA',
#  'THE_TRAGEDY_OF_KING_LEAR_JESSICA',
#  'THE_TRAGEDY_OF_KING_LEAR_JULIET',
#  'THE_TRAGEDY_OF_KING_LEAR_KATHARINE',
#  'THE_TRAGEDY_OF_KING_LEAR_KING',
#  'THE_TRAGEDY_OF_KING_LEAR_KNOWLEDGE',
#  'THE_TRAGEDY_OF_KING_LEAR_LADY_MACBETH',
#  'THE_TRAGEDY_OF_KING_LEAR_LADY_MACDUFF',
#  'THE_TRAGEDY_OF_KING_LEAR_LAUNCELOT',
#  'THE_TRAGEDY_OF_KING_LEAR_LENNOX',
#  'THE_TRAGEDY_OF_KING_LEAR_LEONARDO',
#  'THE_TRAGEDY_OF_KING_LEAR_LION',
#  'THE_TRAGEDY_OF_KING_LEAR_LONGAVILLE',
#  'THE_TRAGEDY_OF_KING_LEAR_LORD',
#  'THE_TRAGEDY_OF_KING_LEAR_LORDS',
#  'THE_TRAGEDY_OF_KING_LEAR_LORENZO',
#  'THE_TRAGEDY_OF_KING_LEAR_LUCIO',
#  'THE_TRAGEDY_OF_KING_LEAR_LYSANDER',
#  'THE_TRAGEDY_OF_KING_LEAR_MACBETH',
#  'THE_TRAGEDY_OF_KING_LEAR_MACDUFF',
#  'THE_TRAGEDY_OF_KING_LEAR_MALCOLM',
#  'THE_TRAGEDY_OF_KING_LEAR_MAN',
#  'THE_TRAGEDY_OF_KING_LEAR_MARCADE',
#  'THE_TRAGEDY_OF_KING_LEAR_MARIA',
#  'THE_TRAGEDY_OF_KING_LEAR_MARIANA',
#  'THE_TRAGEDY_OF_KING_LEAR_MENTEITH',
#  'THE_TRAGEDY_OF_KING_LEAR_MESSENGER',
#  'THE_TRAGEDY_OF_KING_LEAR_MOON',
#  'THE_TRAGEDY_OF_KING_LEAR_MOONSHINE',
#  'THE_TRAGEDY_OF_KING_LEAR_MOTH',
#  'THE_TRAGEDY_OF_KING_LEAR_MRS',
#  'THE_TRAGEDY_OF_KING_LEAR_MURTHERER',
#  'THE_TRAGEDY_OF_KING_LEAR_NATHANIEL',
#  'THE_TRAGEDY_OF_KING_LEAR_NERISSA',
#  'THE_TRAGEDY_OF_KING_LEAR_NYM',
#  'THE_TRAGEDY_OF_KING_LEAR_OBERON',
#  'THE_TRAGEDY_OF_KING_LEAR_OLD_MAN',
#  'THE_TRAGEDY_OF_KING_LEAR_PAGE',
#  'THE_TRAGEDY_OF_KING_LEAR_PETER',
#  'THE_TRAGEDY_OF_KING_LEAR_PHILOSTRATE',
#  'THE_TRAGEDY_OF_KING_LEAR_PISTOL',
#  'THE_TRAGEDY_OF_KING_LEAR_POMPEY',
#  'THE_TRAGEDY_OF_KING_LEAR_PORTER',
#  'THE_TRAGEDY_OF_KING_LEAR_PORTIA',
#  'THE_TRAGEDY_OF_KING_LEAR_PRINCESS_OF_FRANCE',
#  'THE_TRAGEDY_OF_KING_LEAR_PRINCE_OF_MOROCCO',
#  'THE_TRAGEDY_OF_KING_LEAR_PROLOGUE',
#  'THE_TRAGEDY_OF_KING_LEAR_PROVOST',
#  'THE_TRAGEDY_OF_KING_LEAR_PUCK',
#  'THE_TRAGEDY_OF_KING_LEAR_PYRAMUS',
#  'THE_TRAGEDY_OF_KING_LEAR_QUICKLY',
#  'THE_TRAGEDY_OF_KING_LEAR_QUINCE',
#  'THE_TRAGEDY_OF_KING_LEAR_ROBIN',
#  'THE_TRAGEDY_OF_KING_LEAR_ROSALINE',
#  'THE_TRAGEDY_OF_KING_LEAR_ROSS',
#  'THE_TRAGEDY_OF_KING_LEAR_RUGBY',
#  'THE_TRAGEDY_OF_KING_LEAR_SALERIO',
#  'THE_TRAGEDY_OF_KING_LEAR_SECOND_APPARITION',
#  'THE_TRAGEDY_OF_KING_LEAR_SECOND_FAIRY',
#  'THE_TRAGEDY_OF_KING_LEAR_SECOND_GENTLEMAN',
#  'THE_TRAGEDY_OF_KING_LEAR_SECOND_MURTHERER',
#  'THE_TRAGEDY_OF_KING_LEAR_SECOND_WITCH',
#  'THE_TRAGEDY_OF_KING_LEAR_SERGEANT',
#  'THE_TRAGEDY_OF_KING_LEAR_SERVANT',
#  'THE_TRAGEDY_OF_KING_LEAR_SERVINGMAN',
#  'THE_TRAGEDY_OF_KING_LEAR_SEYTON',
#  'THE_TRAGEDY_OF_KING_LEAR_SHALLOW',
#  'THE_TRAGEDY_OF_KING_LEAR_SHYLOCK',
#  'THE_TRAGEDY_OF_KING_LEAR_SIMPLE',
#  'THE_TRAGEDY_OF_KING_LEAR_SIWARD',
#  'THE_TRAGEDY_OF_KING_LEAR_SLENDER',
#  'THE_TRAGEDY_OF_KING_LEAR_SNOUT',
#  'THE_TRAGEDY_OF_KING_LEAR_SNUG',
#  'THE_TRAGEDY_OF_KING_LEAR_SOLANIO',
#  'THE_TRAGEDY_OF_KING_LEAR_SON',
#  'THE_TRAGEDY_OF_KING_LEAR_STARVELING',
#  'THE_TRAGEDY_OF_KING_LEAR_STEPHANO',
#  'THE_TRAGEDY_OF_KING_LEAR_THESEUS',
#  'THE_TRAGEDY_OF_KING_LEAR_THIRD_APPARITION',
#  'THE_TRAGEDY_OF_KING_LEAR_THIRD_MURTHERER',
#  'THE_TRAGEDY_OF_KING_LEAR_THIRD_WITCH',
#  'THE_TRAGEDY_OF_KING_LEAR_THISBY',
#  'THE_TRAGEDY_OF_KING_LEAR_TITANIA',
#  'THE_TRAGEDY_OF_KING_LEAR_TUBAL',
#  'THE_TRAGEDY_OF_KING_LEAR_WALL',
#  'THE_TRAGEDY_OF_KING_LEAR_WILLIAM',
#  'THE_TRAGEDY_OF_KING_LEAR_YOUNG_SIWARD']

# %%
example = train_data.create_tf_dataset_for_client('ALL_S_WELL_THAT_ENDS_WELL_ANTONY')
lenx = 0
for x in example:
    print(x['snippets'])
    lenx += 1
print(lenx)
# Out:
# tf.Tensor(b'Fulvia is dead.', shape=(), dtype=string)
# tf.Tensor(b'What is his strength by land?', shape=(), dtype=string)
# tf.Tensor(b"There's a great spirit gone! Thus did I desire it.\nWhat our contempts doth often hurl from us\nWe wish it ours again; the present pleasure,\nBy revolution low'ring, does become\nThe opposite of itself. She's good, being gone;\nThe hand could pluck her back that shov'd her on.\nI must from this enchanting queen break off.\nTen thousand harms, more than the ills I know,\nMy idleness doth hatch. How now, Enobarbus!\n                Re-enter ENOBARBUS\nI must with haste from hence.", shape=(), dtype=string)
# tf.Tensor(b'Sit, sir.', shape=(), dtype=string)
# tf.Tensor(b"To this good purpose, that so fairly shows,\nDream of impediment! Let me have thy hand.\nFurther this act of grace; and from this hour\nThe heart of brothers govern in our loves\nAnd sway our great designs!\nI did not think to draw my sword 'gainst Pompey;", shape=(), dtype=string)
# tf.Tensor(b"This foul Egyptian hath betrayed me.\nMy fleet hath yielded to the foe, and yonder\nThey cast their caps up and carouse together\nLike friends long lost. Triple-turn'd whore! 'tis thou\nHast sold me to this novice; and my heart\nMakes only wars on thee. Bid them all fly;\nFor when I am reveng'd upon my charm,\nI have done all. Bid them all fly; begone.       Exit SCARUS\nO sun, thy uprise shall I see no more!\nFortune and Antony part here; even here\nDo we shake hands. All come to this? The hearts\nThat spaniel'd me at heels, to whom I gave\nTheir wishes, do discandy, melt their sweets\nOn blossoming Caesar; and this pine is bark'd\nThat overtopp'd them all. Betray'd I am.\nO this false soul of Egypt! this grave charm-\nWhose eye beck'd forth my wars and call'd them home,\nWhose bosom was my crownet, my chief end-\nLike a right gypsy hath at fast and loose\nBeguil'd me to the very heart of loss.\nWhat, Eros, Eros!\n                  Enter CLEOPATRA\nAh, thou spell! Avaunt!\nVanish, or I shall give thee thy deserving", shape=(), dtype=string)
# tf.Tensor(b"I wish I could be made so many men,\nAnd all of you clapp'd up together in\nAn Antony, that I might do you service\nSo good as you have done.\nWell, my good fellows, wait on me to-night.", shape=(), dtype=string)
# tf.Tensor(b'Now, Eros.', shape=(), dtype=string)
# tf.Tensor(b"Once for thy sprightly comfort, and tenfold\nFor thy good valour. Come thee on.\nSCARUS. I'll halt after.                              Exeunt\n                     SCENE VIII.\n           Under the walls of Alexandria\n    Alarum. Enter ANTONY, again in a march; SCARUS\n                    with others\nWe have beat him to his camp. Run one before", shape=(), dtype=string)
# tf.Tensor(b'And fair words to them.', shape=(), dtype=string)
# tf.Tensor(b"That call'd me timelier than my purpose hither;\nFor I have gained by't.\nThat will I, Pompey.", shape=(), dtype=string)
# tf.Tensor(b"To run and show their shoulders. Friends, be gone;\nI have myself resolv'd upon a course\nWhich has no need of you; be gone.\nMy treasure's in the harbour, take it. O,\nI follow'd that I blush to look upon.\nMy very hairs do mutiny; for the white\nReprove the brown for rashness, and they them\nFor fear and doting. Friends, be gone; you shall\nHave letters from me to some friends that will\nSweep your way for you. Pray you look not sad,\nNor make replies of loathness; take the hint\nWhich my despair proclaims. Let that be left\nWhich leaves itself. To the sea-side straight way.\nI will possess you of that ship and treasure.\nLeave me, I pray, a little; pray you now;\nNay, do so, for indeed I have lost command;\nTherefore I pray you. I'll see you by and by.    [Sits down]\n        Enter CLEOPATRA, led by CHARMIAN and IRAS,\n                     EROS following\nNo, no, no, no, no.", shape=(), dtype=string)
# tf.Tensor(b'No, my chuck. Eros! Come, mine armour, Eros!', shape=(), dtype=string)
# tf.Tensor(b'I am dying, Egypt, dying.', shape=(), dtype=string)
# tf.Tensor(b"Authority melts from me. Of late, when I cried 'Ho!'\nLike boys unto a muss, kings would start forth\nAnd cry 'Your will?' Have you no ears? I am\nAntony yet.\n                   Enter servants\nTake hence this Jack and whip him.\nMoon and stars!", shape=(), dtype=string)
# tf.Tensor(b'The armourer of my heart. False, false; this, this.\nWell, well;', shape=(), dtype=string)
# tf.Tensor(b"And, with the rest full-mann'd, from th' head of Actium\nBeat th' approaching Caesar. But if we fail,\nWe then can do't at land.\n                   Enter a MESSENGER\nThy business?\nCan he be there in person? 'Tis impossible-", shape=(), dtype=string)
# tf.Tensor(b'Holds idleness your subject, I should take you\nFor idleness itself.\nLet us go. Come.', shape=(), dtype=string)
# tf.Tensor(b"A vapour sometime like a bear or lion,\nA tower'd citadel, a pendent rock,\nA forked mountain, or blue promontory\nWith trees upon't that nod unto the world\nAnd mock our eyes with air. Thou hast seen these signs;\nThey are black vesper's pageants.\nThat which is now a horse, even with a thought", shape=(), dtype=string)
# tf.Tensor(b'If you can- your reason.', shape=(), dtype=string)
# tf.Tensor(b'Thrice nobler than myself!', shape=(), dtype=string)
# tf.Tensor(b"We have beat them to their beds. What, girl! though grey\nDo something mingle with our younger brown, yet ha' we\nA brain that nourishes our nerves, and can\nGet goal for goal of youth. Behold this man;\nCommend unto his lips thy favouring hand-\nKiss it, my warrior- he hath fought to-day\nAs if a god in hate of mankind had\nDestroyed in such a shape.\nHe has deserv'd it, were it carbuncled", shape=(), dtype=string)
# tf.Tensor(b"Let your best love draw to that point which seeks\nBest to preserve it. If I lose mine honour,\nI lose myself; better I were not yours\nThan yours so branchless. But, as you requested,\nYourself shall go between's. The meantime, lady,\nI'll raise the preparation of a war\nShall stain your brother. Make your soonest haste;\nSo your desires are yours.\nWhen it appears to you where this begins,", shape=(), dtype=string)
# tf.Tensor(b'These strong Egyptian fetters I must break,\nOr lose myself in dotage.\n             Enter another MESSENGER with a letter\nWhat are you?\nWhere died she?', shape=(), dtype=string)
# tf.Tensor(b'Well, what worst?', shape=(), dtype=string)
# tf.Tensor(b'I am satisfied.', shape=(), dtype=string)
# tf.Tensor(b"Would we had spoke together! Haste we for it.\nYet, ere we put ourselves in arms, dispatch we\nThe business we have talk'd of.\nLet us, Lepidus,", shape=(), dtype=string)
# tf.Tensor(b'For he hath laid strange courtesies and great\nOf late upon me. I must thank him only,\nLest my remembrance suffer ill report;\nAt heel of that, defy him.\nWhere lies he?', shape=(), dtype=string)
# tf.Tensor(b"Which might have well becom'd the best of men\nTo taunt at slackness. Canidius, we\nWill fight with him by sea.\nFor that he dares us to't.", shape=(), dtype=string)
# tf.Tensor(b'And these the showers to bring it on. Be cheerful.\nHer tongue will not obey her heart, nor can', shape=(), dtype=string)
# tf.Tensor(b"It is asham'd to bear me. Friends, come hither.\nI am so lated in the world that I\nHave lost my way for ever. I have a ship\nLaden with gold; take that; divide it. Fly,\nAnd make your peace with Caesar.\nI have fled myself, and have instructed cowards", shape=(), dtype=string)
# tf.Tensor(b'I learn you take things ill which are not so,', shape=(), dtype=string)
# tf.Tensor(b"Now for the love of Love and her soft hours,\nLet's not confound the time with conference harsh;\nThere's not a minute of our lives should stretch\nWithout some pleasure now. What sport to-night?\nFie, wrangling queen!", shape=(), dtype=string)
# tf.Tensor(b"Hark, Ventidius.\n'Tis spoken well.", shape=(), dtype=string)
# tf.Tensor(b"It is shap'd, sir, like itself, and it is as broad as it", shape=(), dtype=string)
# tf.Tensor(b'Fulvia is dead.', shape=(), dtype=string)
# tf.Tensor(b"And give true evidence to his love, which stands\nAn honourable trial.\nYou'll heat my blood; no more.", shape=(), dtype=string)
# tf.Tensor(b"Now the witch take me if I meant it thus!\nGrace grow where those drops fall! My hearty friends,\nYou take me in too dolorous a sense;\nFor I spake to you for your comfort, did desire you\nTo burn this night with torches. Know, my hearts,\nI hope well of to-morrow, and will lead you\nWhere rather I'll expect victorious life\nThan death and honour. Let's to supper, come,\nAnd drown consideration.                              Exeunt\n                      SCENE III.\n         Alexandria. Before CLEOPATRA's palace\n             Enter a company of soldiers\nEros! mine armour, Eros!", shape=(), dtype=string)
# tf.Tensor(b"And then when poisoned hours had bound me up\nFrom mine own knowledge. As nearly as I may,\nI'll play the penitent to you; but mine honesty\nShall not make poor my greatness, nor my power\nWork without it. Truth is, that Fulvia,\nTo have me out of Egypt, made wars here;\nFor which myself, the ignorant motive, do\nSo far ask pardon as befits mine honour\nTo stoop in such a case.\nThou art a soldier only. Speak no more.", shape=(), dtype=string)
# tf.Tensor(b"What's the matter?", shape=(), dtype=string)
# tf.Tensor(b'You have heard much.', shape=(), dtype=string)
# tf.Tensor(b"I'll wrestle with you in my strength of love.\nLook, here I have you; thus I let you go,\nAnd give you to the gods.\nFarewell!                       Trumpets sound. Exeunt", shape=(), dtype=string)
# tf.Tensor(b"If I would say 'Agrippa, be it so,'\nTo make this good?\nMay I never", shape=(), dtype=string)
# tf.Tensor(b'A most unnoble swerving.\nO, whither hast thou led me, Egypt? See', shape=(), dtype=string)
# tf.Tensor(b"[To CAESAR] Thus do they, sir: they take the flow o' th'", shape=(), dtype=string)
# tf.Tensor(b'                   Enter a MESSENGER\nGrates me the sum.', shape=(), dtype=string)
# tf.Tensor(b'The gods best know-', shape=(), dtype=string)
# tf.Tensor(b'Divide me from your bosom.\nGood night, sir. My Octavia,', shape=(), dtype=string)
# tf.Tensor(b'Make me not offended', shape=(), dtype=string)
# tf.Tensor(b'It ripens towards it. Strike the vessels, ho!', shape=(), dtype=string)
# tf.Tensor(b"I'll fight at sea.", shape=(), dtype=string)
# tf.Tensor(b'Let Rome in Tiber melt, and the wide arch', shape=(), dtype=string)
# tf.Tensor(b"Detain no jot, I charge thee. Write to him-\nI will subscribe- gentle adieus and greetings;\nSay that I wish he never find more cause\nTo change a master. O, my fortunes have\nCorrupted honest men! Dispatch. Enobarbus!            Exeunt\n                     SCENE VI.\n             Alexandria. CAESAR'S camp\n   Flourish. Enter AGRIPPA, CAESAR, With DOLABELLA\n                   and ENOBARBUS\nThou bleed'st apace.", shape=(), dtype=string)
# tf.Tensor(b"The wine peep through their scars. Come on, my queen,\nThere's sap in't yet. The next time I do fight\nI'll make death love me; for I will contend\nEven with his pestilent scythe.     Exeunt all but ENOBARBUS\nHe will not fight with me, Domitius?", shape=(), dtype=string)
# tf.Tensor(b"This morning, like the spirit of a youth\nThat means to be of note, begins betimes.\nSo, so. Come, give me that. This way. Well said.\nFare thee well, dame, whate'er becomes of me.\nThis is a soldier's kiss. Rebukeable,\nAnd worthy shameful check it were, to stand\nOn more mechanic compliment; I'll leave thee\nNow like a man of steel. You that will fight,\nFollow me close; I'll bring you to't. Adieu.\n                  Exeunt ANTONY, EROS, CAPTAINS and soldiers\nWould thou and those thy scars had once prevail'd", shape=(), dtype=string)
# tf.Tensor(b"Unarm, Eros; the long day's task is done,", shape=(), dtype=string)
# tf.Tensor(b"Not Caesar's valour hath o'erthrown Antony,\nBut Antony's hath triumph'd on itself.\nI am dying, Egypt, dying; only", shape=(), dtype=string)
# tf.Tensor(b'The business she hath broached in the state', shape=(), dtype=string)
# tf.Tensor(b'The rack dislimns, and makes it indistinct,\nAs water is in water.\nMy good knave Eros, now thy captain is', shape=(), dtype=string)
# tf.Tensor(b'Of what I have begun.\nLet him that loves me, strike me dead.', shape=(), dtype=string)
# tf.Tensor(b'Forbear me.                             Exit MESSENGER', shape=(), dtype=string)
# tf.Tensor(b"Lepidus, let him speak.\nThe honour is sacred which he talks on now,\nSupposing that I lack'd it. But on, Caesar:\nThe article of my oath-\nNeglected, rather;", shape=(), dtype=string)
# tf.Tensor(b'Go, Eros, send his treasure after; do it;', shape=(), dtype=string)
# tf.Tensor(b"That from Tarentum and Brundusium\nHe could so quickly cut the Ionian sea,\nAnd take in Toryne?- You have heard on't, sweet?\nA good rebuke,", shape=(), dtype=string)
# tf.Tensor(b"His sword e'en like a dancer, while I struck\nThe lean and wrinkled Cassius; and 'twas I\nThat the mad Brutus ended; he alone\nDealt on lieutenantry, and no practice had\nIn the brave squares of war. Yet now- no matter.\nI have offended reputation-", shape=(), dtype=string)
# tf.Tensor(b"But when we in our viciousness grow hard-\nO misery on't!- the wise gods seel our eyes,\nIn our own filth drop our clear judgments, make us\nAdore our errors, laugh at's while we strut\nTo our confusion.\nI found you as a morsel cold upon", shape=(), dtype=string)
# tf.Tensor(b"She hath betray'd me, and shall die the death.\nDead then?", shape=(), dtype=string)
# tf.Tensor(b"To make me fight at land!\nWho's gone this morning?", shape=(), dtype=string)
# tf.Tensor(b"Read not my blemishes in the world's report.\nI have not kept my square; but that to come\nShall all be done by th' rule. Good night, dear lady.\nNow, sirrah, you do wish yourself in Egypt?", shape=(), dtype=string)
# tf.Tensor(b'But that your royalty', shape=(), dtype=string)
# tf.Tensor(b"Name Cleopatra as she is call'd in Rome.\nRail thou in Fulvia's phrase, and taunt my faults\nWith such full licence as both truth and malice\nHave power to utter. O, then we bring forth weeds\nWhen our quick minds lie still, and our ills told us\nIs as our earing. Fare thee well awhile.\nFrom Sicyon, ho, the news! Speak there!", shape=(), dtype=string)
# tf.Tensor(b"Come, let's all take hands,", shape=(), dtype=string)
# tf.Tensor(b"Here's to Caesar!\nBe a child o' th' time.", shape=(), dtype=string)
# tf.Tensor(b"He that unbuckles this, till we do please\nTo daff't for our repose, shall hear a storm.\nThou fumblest, Eros, and my queen's a squire\nMore tight at this than thou. Dispatch. O love,\nThat thou couldst see my wars to-day, and knew'st\nThe royal occupation! Thou shouldst see\nA workman in't.\n               Enter an armed SOLDIER\nGood-morrow to thee. Welcome.\nThou look'st like him that knows a warlike charge.\nTo business that we love we rise betime,\nAnd go to't with delight.\n'Tis well blown, lads.", shape=(), dtype=string)
# tf.Tensor(b'Agrippa further speak.\nWill Caesar speak?', shape=(), dtype=string)
# tf.Tensor(b'Not lack your company.\nThe world and my great office will sometimes', shape=(), dtype=string)
# tf.Tensor(b"Like holy Phoebus' car. Give me thy hand.\nThrough Alexandria make a jolly march;\nBear our hack'd targets like the men that owe them.\nHad our great palace the capacity\nTo camp this host, we all would sup together,\nAnd drink carouses to the next day's fate,\nWhich promises royal peril. Trumpeters,\nWith brazen din blast you the city's ear;\nMake mingle with our rattling tabourines,\nThat heaven and earth may strike their sounds together\nApplauding our approach.                              Exeunt\n                     SCENE IX.\n                  CAESAR'S camp\n  Enter a CENTURION and his company; ENOBARBUS follows\nTheir preparation is to-day by sea;", shape=(), dtype=string)
# tf.Tensor(b'You do mistake your business; my brother never', shape=(), dtype=string)
# tf.Tensor(b"That were excusable, that and thousands more\nOf semblable import- but he hath wag'd\nNew wars 'gainst Pompey; made his will, and read it\nTo public ear;\nSpoke scandy of me; when perforce he could not\nBut pay me terms of honour, cold and sickly\nHe vented them, most narrow measure lent me;\nWhen the best hint was given him, he not took't,\nOr did it from his teeth.\nGentle Octavia,", shape=(), dtype=string)
# tf.Tensor(b"And say 'God quit you!' be familiar with\nMy playfellow, your hand, this kingly seal\nAnd plighter of high hearts! O that I were\nUpon the hill of Basan to outroar\nThe horned herd! For I have savage cause,\nAnd to proclaim it civilly were like\nA halter'd neck which does the hangman thank\nFor being yare about him.\n          Re-enter a SERVANT with THYREUS\nIs he whipt?\nCried he? and begg'd 'a pardon?", shape=(), dtype=string)
# tf.Tensor(b'Is he gone?', shape=(), dtype=string)
# tf.Tensor(b'Then let it do at once', shape=(), dtype=string)
# tf.Tensor(b'Cleopatra-', shape=(), dtype=string)
# tf.Tensor(b'Get thee gone.', shape=(), dtype=string)
# tf.Tensor(b"I have liv'd in such dishonour that the gods\nDetest my baseness. I, that with my sword\nQuarter'd the world, and o'er green Neptune's back\nWith ships made cities, condemn myself to lack\nThe courage of a woman; less noble mind\nThan she which by her death our Caesar tells\n'I am conqueror of myself.' Thou art sworn, Eros,\nThat, when the exigent should come- which now\nIs come indeed- when I should see behind me\nTh' inevitable prosecution of\nDisgrace and horror, that, on my command,\nThou then wouldst kill me. Do't; the time is come.\nThou strik'st not me; 'tis Caesar thou defeat'st.\nPut colour in thy cheek.\nEros,", shape=(), dtype=string)
# tf.Tensor(b"Call forth my household servants; let's to-night\nBe bounteous at our meal.\n            Enter three or four servitors\nGive me thy hand,\nThou has been rightly honest. So hast thou;\nThou, and thou, and thou. You have serv'd me well,\nAnd kings have been your fellows.\nAnd thou art honest too.", shape=(), dtype=string)
# tf.Tensor(b"Look here, and at thy sovereign leisure read\nThe garboils she awak'd. At the last, best.\nSee when and where she died.\nQuarrel no more, but be prepar'd to know", shape=(), dtype=string)
# tf.Tensor(b'hath breadth; it is just so high as it is, and moves with it own\norgans. It lives by that which nourisheth it, and the elements\nonce out of it, it transmigrates.\nOf it own colour too.', shape=(), dtype=string)
# tf.Tensor(b'In your distrust.\nYou shall not find,', shape=(), dtype=string)
# tf.Tensor(b'Or being, concern you not.\nMy being in Egypt, Caesar,', shape=(), dtype=string)
# tf.Tensor(b'The Queen shall then have courtesy, so she', shape=(), dtype=string)
# tf.Tensor(b'I will reward thee', shape=(), dtype=string)
# tf.Tensor(b"Even such a body. Here I am Antony;\nYet cannot hold this visible shape, my knave.\nI made these wars for Egypt; and the Queen-\nWhose heart I thought I had, for she had mine,\nWhich, whilst it was mine, had annex'd unto't\nA million moe, now lost- she, Eros, has\nPack'd cards with Caesar, and false-play'd my glory\nUnto an enemy's triumph.\nNay, weep not, gentle Eros; there is left us\nOurselves to end ourselves.\n                     Enter MARDIAN\nO, thy vile lady!\nShe has robb'd me of my sword.\nHence, saucy eunuch; peace!", shape=(), dtype=string)
# tf.Tensor(b'To grace it with your sorrows. Bid that welcome\nWhich comes to punish us, and we punish it,\nSeeming to bear it lightly. Take me up.\nI have led you oft; carry me now, good friends,\nAnd have my thanks for all.           Exeunt, hearing ANTONY\n                     SCENE XV.\n               Alexandria. A monument\n  Enter CLEOPATRA and her maids aloft, with CHARMIAN\n                     and IRAS\nPeace!', shape=(), dtype=string)
# tf.Tensor(b"Whose fortunes shall rise higher, Caesar's or mine?\nSpeak this no more.", shape=(), dtype=string)
# tf.Tensor(b'So is the fame.', shape=(), dtype=string)
# tf.Tensor(b'Most sweet queen-', shape=(), dtype=string)
# tf.Tensor(b'No further, sir.', shape=(), dtype=string)
# tf.Tensor(b"Scant not my cups, and make as much of me\nAs when mine empire was your fellow too,\nAnd suffer'd my command.\nTend me to-night;", shape=(), dtype=string)
# tf.Tensor(b"                     Exeunt ANTONY, CLEOPATRA, and ENOBARBUS\nSet we our squadrons on yon side o' th' hill,", shape=(), dtype=string)
# tf.Tensor(b"And we must sleep. That thou depart'st hence safe\nDoes pay thy labour richly. Go.                 Exit MARDIAN\nOff, pluck off!\nThe sevenfold shield of Ajax cannot keep\nThe battery from my heart. O, cleave, my sides!\nHeart, once be stronger than thy continent,\nCrack thy frail case. Apace, Eros, apace.-\nNo more a soldier. Bruised pieces, go;\nYou have been nobly borne.- From me awhile.        Exit EROS\nI will o'ertake thee, Cleopatra, and\nWeep for my pardon. So it must be, for now\nAll length is torture. Since the torch is out,\nLie down, and stray no farther. Now all labour\nMars what it does; yea, very force entangles\nItself with strength. Seal then, and all is done.\nEros!- I come, my queen.- Eros!- Stay for me;\nWhere souls do couch on flowers, we'll hand in hand,\nAnd with our sprightly port make the ghosts gaze.\nDido and her Aeneas shall want troops,\nAnd all the haunt be ours.- Come, Eros, Eros!\n                   Re-enter EROS\nSince Cleopatra died,", shape=(), dtype=string)
# tf.Tensor(b"And blemish Caesar's triumph. Let him take thee\nAnd hoist thee up to the shouting plebeians;\nFollow his chariot, like the greatest spot\nOf all thy sex; most monster-like, be shown\nFor poor'st diminutives, for doits, and let\nPatient Octavia plough thy visage up\nWith her prepared nails.                      Exit CLEOPATRA\n'Tis well th'art gone,\nIf it be well to live; but better 'twere\nThou fell'st into my fury, for one death\nMight have prevented many. Eros, ho!\nThe shirt of Nessus is upon me; teach me,\nAlcides, thou mine ancestor, thy rage;\nLet me lodge Lichas on the horns o' th' moon,\nAnd with those hands that grasp'd the heaviest club\nSubdue my worthiest self. The witch shall die.\nTo the young Roman boy she hath sold me, and I fall\nUnder this plot. She dies for't. Eros, ho!              Exit\n                      SCENE XIII.\n           Alexandria. CLEOPATRA's palace\n  Enter CLEOPATRA, CHARMIAN, IRAS, and MARDIAN\nEros, thou yet behold'st me?", shape=(), dtype=string)
# tf.Tensor(b'Dead.', shape=(), dtype=string)
# tf.Tensor(b"What it is worth embrac'd.\nI have heard it, Pompey,", shape=(), dtype=string)
# tf.Tensor(b'Cannot endure my absence.\nNo more light answers. Let our officers', shape=(), dtype=string)
# tf.Tensor(b"Have notice what we purpose. I shall break\nThe cause of our expedience to the Queen,\nAnd get her leave to part. For not alone\nThe death of Fulvia, with more urgent touches,\nDo strongly speak to us; but the letters to\nOf many our contriving friends in Rome\nPetition us at home. Sextus Pompeius\nHath given the dare to Caesar, and commands\nThe empire of the sea; our slippery people,\nWhose love is never link'd to the deserver\nTill his deserts are past, begin to throw\nPompey the Great and all his dignities\nUpon his son; who, high in name and power,\nHigher than both in blood and life, stands up\nFor the main soldier; whose quality, going on,\nThe sides o' th' world may danger. Much is breeding\nWhich, like the courser's hair, hath yet but life\nAnd not a serpent's poison. Say our pleasure,\nTo such whose place is under us, requires\nOur quick remove from hence.\nI am sorry to give breathing to my purpose-", shape=(), dtype=string)
# tf.Tensor(b'We shall thrive now. Seest thou, my good fellow?\nGo put on thy defences.\nRarely, rarely!', shape=(), dtype=string)
# tf.Tensor(b'How now, lady!', shape=(), dtype=string)
# tf.Tensor(b'Sufficing strokes for death.\nWhen did she send thee?', shape=(), dtype=string)
# tf.Tensor(b'Made out of her impatience- which not wanted\nShrewdness of policy too- I grieving grant\nDid you too much disquiet. For that you must\nBut say I could not help it.\nSir,', shape=(), dtype=string)
# tf.Tensor(b"Strange that his power should be. Canidius,\nOur nineteen legions thou shalt hold by land,\nAnd our twelve thousand horse. We'll to our ship.\nAway, my Thetis!\n                   Enter a SOLDIER\nHow now, worthy soldier?\nWell, well- away.", shape=(), dtype=string)
# tf.Tensor(b"And let the Queen know of our gests. To-morrow,\nBefore the sun shall see's, we'll spill the blood\nThat has to-day escap'd. I thank you all;\nFor doughty-handed are you, and have fought\nNot as you serv'd the cause, but as't had been\nEach man's like mine; you have shown all Hectors.\nEnter the city, clip your wives, your friends,\nTell them your feats; whilst they with joyful tears\nWash the congealment from your wounds and kiss\nThe honour'd gashes whole.\n             Enter CLEOPATRA, attended\n[To SCARUS] Give me thy hand-\nTo this great fairy I'll commend thy acts,\nMake her thanks bless thee. O thou day o' th' world,\nChain mine arm'd neck. Leap thou, attire and all,\nThrough proof of harness to my heart, and there\nRide on the pants triumphing.\nMine nightingale,", shape=(), dtype=string)
# tf.Tensor(b'Now, my dearest queen-', shape=(), dtype=string)
# tf.Tensor(b'Our separation so abides and flies\nThat thou, residing here, goes yet with me,\nAnd I, hence fleeting, here remain with thee.\nAway!                                                 Exeunt\nIf we compose well here, to Parthia.', shape=(), dtype=string)
# tf.Tensor(b"What was't to you?\nHow intend you- practis'd?", shape=(), dtype=string)
# tf.Tensor(b"And am well studied for a liberal thanks\nWhich I do owe you.\nThe beds i' th' East are soft; and thanks to you,", shape=(), dtype=string)
# tf.Tensor(b"Though you be therein curious, the least cause\nFor what you seem to fear. So the gods keep you,\nAnd make the hearts of Romans serve your ends!\nWe will here part.\nThe April's in her eyes. It is love's spring,", shape=(), dtype=string)
# tf.Tensor(b'Yes, my lord, yes. He at Philippi kept', shape=(), dtype=string)
# tf.Tensor(b'Where is she?', shape=(), dtype=string)
# tf.Tensor(b"Till that the conquering wine hath steep'd our sense\nIn soft and delicate Lethe.\nAnd shall, sir. Give's your hand.", shape=(), dtype=string)
# tf.Tensor(b'You wrong this presence; therefore speak no more.', shape=(), dtype=string)
# tf.Tensor(b'I must be gone.', shape=(), dtype=string)
# tf.Tensor(b'What power is in Agrippa,', shape=(), dtype=string)
# tf.Tensor(b'Hear me, queen:', shape=(), dtype=string)
# tf.Tensor(b"Keep off them, for you sink.\nBear him ashore. I'll pledge it for him, Pompey.", shape=(), dtype=string)
# tf.Tensor(b"I'll leave you, lady.", shape=(), dtype=string)
# tf.Tensor(b"Of youth upon him; from which the world should note\nSomething particular. His coin, ships, legions,\nMay be a coward's whose ministers would prevail\nUnder the service of a child as soon\nAs i' th' command of Caesar. I dare him therefore\nTo lay his gay comparisons apart,\nAnd answer me declin'd, sword against sword,\nOurselves alone. I'll write it. Follow me.\n                                Exeunt ANTONY and EUPHRONIUS\nFavours, by Jove that thunders!", shape=(), dtype=string)
# tf.Tensor(b'I am not married, Caesar. Let me hear', shape=(), dtype=string)
# tf.Tensor(b"Wouldst thou be window'd in great Rome and see\nThy master thus with pleach'd arms, bending down\nHis corrigible neck, his face subdu'd\nTo penetrative shame, whilst the wheel'd seat\nOf fortunate Caesar, drawn before him, branded\nHis baseness that ensued?\nCome, then; for with a wound I must be cur'd.", shape=(), dtype=string)
# tf.Tensor(b'Say to me,', shape=(), dtype=string)
# tf.Tensor(b"My heart was to thy rudder tied by th' strings,\nAnd thou shouldst tow me after. O'er my spirit\nThy full supremacy thou knew'st, and that\nThy beck might from the bidding of the gods\nCommand me.\nNow I must", shape=(), dtype=string)
# tf.Tensor(b"What say'st thou?", shape=(), dtype=string)
# tf.Tensor(b"The thing why thou hast drawn it.\n'Tis said, man; and farewell.", shape=(), dtype=string)
# tf.Tensor(b'To-morrow, soldier,', shape=(), dtype=string)
# tf.Tensor(b"We please them not by land.\nI would they'd fight i' th' fire or i' th' air;", shape=(), dtype=string)
# tf.Tensor(b'If that thy father live, let him repent', shape=(), dtype=string)
# tf.Tensor(b'Bear me, good friends, where Cleopatra bides;', shape=(), dtype=string)
# tf.Tensor(b'I here importune death awhile, until\nOf many thousand kisses the poor last\nI lay upon thy lips.\nO, quick, or I am gone.', shape=(), dtype=string)
# tf.Tensor(b"Sometime we see a cloud that's dragonish;", shape=(), dtype=string)
# tf.Tensor(b'Why should he not?', shape=(), dtype=string)
# tf.Tensor(b'               Enter EROS with armour\nCome, good fellow, put mine iron on.\nIf fortune be not ours to-day, it is\nBecause we brave her. Come.\nAh, let be, let be! Thou art', shape=(), dtype=string)
# tf.Tensor(b'Were we before our arinies, and to fight,\nI should do thus.                                 [Flourish]\nThank you.', shape=(), dtype=string)
# tf.Tensor(b'Give me some wine, and let me speak a little.\nOne word, sweet queen:', shape=(), dtype=string)
# tf.Tensor(b"Whip him. Were't twenty of the greatest tributaries\nThat do acknowledge Caesar, should I find them\nSo saucy with the hand of she here- what's her name\nSince she was Cleopatra? Whip him, fellows,\nTill like a boy you see him cringe his face,\nAnd whine aloud for mercy. Take him hence.\nTug him away. Being whipt,", shape=(), dtype=string)
# tf.Tensor(b'With one that ties his points?\nCold-hearted toward me?', shape=(), dtype=string)
# tf.Tensor(b"Thou wast not made his daughter; and be thou sorry\nTo follow Caesar in his triumph, since\nThou hast been whipt for following him. Henceforth\nThe white hand of a lady fever thee!\nShake thou to look on't. Get thee back to Caesar;\nTell him thy entertainment; look thou say\nHe makes me angry with him; for he seems\nProud and disdainful, harping on what I am,\nNot what he knew I was. He makes me angry;\nAnd at this time most easy 'tis to do't,\nWhen my good stars, that were my former guides,\nHave empty left their orbs and shot their fires\nInto th' abysm of hell. If he mislike\nMy speech and what is done, tell him he has\nHipparchus, my enfranched bondman, whom\nHe may at pleasure whip or hang or torture,\nAs he shall like, to quit me. Urge it thou.\nHence with thy stripes, be gone.                Exit THYREUS\nAlack, our terrene moon", shape=(), dtype=string)
# tf.Tensor(b'epicure.\nThese quicksands, Lepidus,', shape=(), dtype=string)
# tf.Tensor(b'Would I had never seen her!', shape=(), dtype=string)
# tf.Tensor(b"Did urge me in his act. I did inquire it,\nAnd have my learning from some true reports\nThat drew their swords with you. Did he not rather\nDiscredit my authority with yours,\nAnd make the wars alike against my stomach,\nHaving alike your cause? Of this my letters\nBefore did satisfy you. If you'll patch a quarrel,\nAs matter whole you have not to make it with,\nIt must not be with this.\nNot so, not so;", shape=(), dtype=string)
# tf.Tensor(b"May be it is the period of your duty.\nHaply you shall not see me more; or if,\nA mangled shadow. Perchance to-morrow\nYou'll serve another master. I look on you\nAs one that takes his leave. Mine honest friends,\nI turn you not away; but, like a master\nMarried to your good service, stay till death.\nTend me to-night two hours, I ask no more,\nAnd the gods yield you for't!\nHo, ho, ho!", shape=(), dtype=string)
# tf.Tensor(b'With the health that Pompey gives him, else he is a very', shape=(), dtype=string)
# tf.Tensor(b"Lament nor sorrow at; but please your thoughts\nIn feeding them with those my former fortunes\nWherein I liv'd the greatest prince o' th' world,\nThe noblest; and do now not basely die,\nNot cowardly put off my helmet to\nMy countryman- a Roman by a Roman\nValiantly vanquish'd. Now my spirit is going\nI can no more.\n", shape=(), dtype=string)
# tf.Tensor(b"Draw that thy honest sword, which thou hast worn\nMost useful for thy country.\nWhen I did make thee free, swor'st thou not then", shape=(), dtype=string)
# tf.Tensor(b"The purposes I bear; which are, or cease,\nAs you shall give th' advice. By the fire\nThat quickens Nilus' slime, I go from hence\nThy soldier, servant, making peace or war\nAs thou affects.\nMy precious queen, forbear,", shape=(), dtype=string)
# tf.Tensor(b'They do retire.', shape=(), dtype=string)
# tf.Tensor(b"In eye of Caesar's battle; from which place\nWe may the number of the ships behold,\nAnd so proceed accordingly.                           Exeunt\n                       SCENE X.\n             Another part of the plain\n    CANIDIUS marcheth with his land army one way\n    over the stage, and TAURUS, the Lieutenant of\n  CAESAR, the other way. After their going in is heard\n               the noise of a sea-fight\n                Alarum. Enter ENOBARBUS\nHark! the land bids me tread no more upon't;", shape=(), dtype=string)
# tf.Tensor(b"'Tis the last service that I shall command you.\nNay, good my fellows, do not please sharp fate", shape=(), dtype=string)
# tf.Tensor(b"He fell upon me ere admitted. Then\nThree kings I had newly feasted, and did want\nOf what I was i' th' morning; but next day\nI told him of myself, which was as much\nAs to have ask'd him pardon. Let this fellow\nBe nothing of our strife; if we contend,\nOut of our question wipe him.\nNo;", shape=(), dtype=string)
# tf.Tensor(b"Will yield us up.\nLet her know't.", shape=(), dtype=string)
# tf.Tensor(b"Caesar sits down in Alexandria, where\nI will oppose his fate. Our force by land\nHath nobly held; our sever'd navy to\nHave knit again, and fleet, threat'ning most sea-like.\nWhere hast thou been, my heart? Dost thou hear, lady?\nIf from the field I shall return once more\nTo kiss these lips, I will appear in blood.\nI and my sword will earn our chronicle.\nThere's hope in't yet.\nI will be treble-sinew'd, hearted, breath'd,", shape=(), dtype=string)
# tf.Tensor(b"Whom everything becomes- to chide, to laugh,\nTo weep; whose every passion fully strives\nTo make itself in thee fair and admir'd.\nNo messenger but thine, and all alone\nTo-night we'll wander through the streets and note\nThe qualities of people. Come, my queen;\nLast night you did desire it. Speak not to us.\n                 Exeunt ANTONY and CLEOPATRA, with the train\nAgainst my brother Lucius?", shape=(), dtype=string)
# tf.Tensor(b'Then must thou needs find out new heaven, new earth.', shape=(), dtype=string)
# tf.Tensor(b"Say to Ventidius I would speak with him.\n                                             Exit SOOTHSAYER\nHe shall to Parthia.- Be it art or hap,\nHe hath spoken true. The very dice obey him;\nAnd in our sports my better cunning faints\nUnder his chance. If we draw lots, he speeds;\nHis cocks do win the battle still of mine,\nWhen it is all to nought, and his quails ever\nBeat mine, inhoop'd, at odds. I will to Egypt;\nAnd though I make this marriage for my peace,\nI' th' East my pleasure lies.\n                   Enter VENTIDIUS\nO, come, Ventidius,\nYou must to Parthia. Your commission's ready;\nFollow me and receive't.                              Exeunt\nThou canst not fear us, Pompey, with thy sails;", shape=(), dtype=string)
# tf.Tensor(b'Of Caesar seek your honour, with your safety. O!\nGentle, hear me:', shape=(), dtype=string)
# tf.Tensor(b'What art thou, fellow?\nApproach there.- Ah, you kite!- Now, gods and devils!', shape=(), dtype=string)
# tf.Tensor(b"Things that are past are done with me. 'Tis thus:\nWho tells me true, though in his tale lie death,\nI hear him as he flatter'd.\nAntony, thou wouldst say.", shape=(), dtype=string)
# tf.Tensor(b"I know you could not lack, I am certain on't,\nVery necessity of this thought, that I,\nYour partner in the cause 'gainst which he fought,\nCould not with graceful eyes attend those wars\nWhich fronted mine own peace. As for my wife,\nI would you had her spirit in such another!\nThe third o' th' world is yours, which with a snaffle\nYou may pace easy, but not such a wife.\nSo much uncurbable, her garboils, Caesar,", shape=(), dtype=string)
# tf.Tensor(b'To the boy Caesar send this grizzled head,\nAnd he will fill thy wishes to the brim\nWith principalities.\nTo him again. Tell him he wears the rose', shape=(), dtype=string)
# tf.Tensor(b"Is now eclips'd, and it portends alone\nThe fall of Antony.\nTo flatter Caesar, would you mingle eyes", shape=(), dtype=string)
# tf.Tensor(b"Of the rang'd empire fall! Here is my space.\nKingdoms are clay; our dungy earth alike\nFeeds beast as man. The nobleness of life\nIs to do thus [emhracing], when such a mutual pair\nAnd such a twain can do't, in which I bind,\nOn pain of punishment, the world to weet\nWe stand up peerless.\nBut stirr'd by Cleopatra.", shape=(), dtype=string)
# tf.Tensor(b"To do this when I bade thee? Do it at once,\nOr thy precedent services are all\nBut accidents unpurpos'd. Draw, and come.\nLo thee!                            [Turning from him]", shape=(), dtype=string)
# tf.Tensor(b"We'll speak with thee at sea; at land thou know'st\nHow much we do o'er-count thee.\nWhich do not be entreated to, but weigh", shape=(), dtype=string)
# tf.Tensor(b"  Nile\nBy certain scales i' th' pyramid; they know\nBy th' height, the lowness, or the mean, if dearth\nOr foison follow. The higher Nilus swells\nThe more it promises; as it ebbs, the seedsman\nUpon the slime and ooze scatters his grain,\nAnd shortly comes to harvest.\nAy, Lepidus.", shape=(), dtype=string)
# tf.Tensor(b"Thou teachest me, O valiant Eros, what\nI should, and thou couldst not. My queen and Eros\nHave, by their brave instruction, got upon me\nA nobleness in record. But I will be\nA bridegroom in my death, and run into't\nAs to a lover's bed. Come, then; and, Eros,\nThy master dies thy scholar. To do thus\n                                      [Falling on his sword]\nI learn'd of thee. How? not dead? not dead?-\nThe guard, ho! O, dispatch me!\n              Enter DERCETAS and a guard\nI have done my work ill, friends. O, make an end", shape=(), dtype=string)
# tf.Tensor(b"Bring him again: the Jack of Caesar's shall\nBear us an errand to him.       Exeunt servants with THYREUS\nYou were half blasted ere I knew you. Ha!\nHave I my pillow left unpress'd in Rome,\nForborne the getting of a lawful race,\nAnd by a gem of women, to be abus'd\nBy one that looks on feeders?\nYou have been a boggler ever.", shape=(), dtype=string)
# tf.Tensor(b"She is cunning past man's thought.", shape=(), dtype=string)
# tf.Tensor(b'They are so.', shape=(), dtype=string)
# tf.Tensor(b"Dead Caesar's trencher. Nay, you were a fragment\nOf Cneius Pompey's, besides what hotter hours,\nUnregist'red in vulgar fame, you have\nLuxuriously pick'd out; for I am sure,\nThough you can guess what temperance should be,\nYou know not what it is.\nTo let a fellow that will take rewards,", shape=(), dtype=string)
# tf.Tensor(b"To the young man send humble treaties, dodge\nAnd palter in the shifts of lowness, who\nWith half the bulk o' th' world play'd as I pleas'd,\nMaking and marring fortunes. You did know\nHow much you were my conqueror, and that\nMy sword, made weak by my affection, would\nObey it on all cause.\nFall not a tear, I say; one of them rates", shape=(), dtype=string)
# tf.Tensor(b"'Tis so. And the tears of it are wet.", shape=(), dtype=string)
# tf.Tensor(b'By sea, by sea.', shape=(), dtype=string)
# tf.Tensor(b"Her heart inform her tongue- the swan's down feather,\nThat stands upon the swell at the full of tide,\nAnd neither way inclines.\nCome, sir, come;", shape=(), dtype=string)
# 182

# %%
raw_example_dataset = train_data.create_tf_dataset_for_client(
    'THE_TRAGEDY_OF_KING_LEAR_KING')
# To allow for future extensions, each entry x
# is an OrderedDict with a single key 'snippets' which contains the text.
for x in raw_example_dataset.take(2):
    print(x['snippets'])
# Out:
# tf.Tensor(b"Live regist'red upon our brazen tombs,\nAnd then grace us in the disgrace of death;\nWhen, spite of cormorant devouring Time,\nTh' endeavour of this present breath may buy\nThat honour which shall bate his scythe's keen edge,\nAnd make us heirs of all eternity.\nTherefore, brave conquerors- for so you are\nThat war against your own affections\nAnd the huge army of the world's desires-\nOur late edict shall strongly stand in force:\nNavarre shall be the wonder of the world;\nOur court shall be a little Academe,\nStill and contemplative in living art.\nYou three, Berowne, Dumain, and Longaville,\nHave sworn for three years' term to live with me\nMy fellow-scholars, and to keep those statutes\nThat are recorded in this schedule here.\nYour oaths are pass'd; and now subscribe your names,\nThat his own hand may strike his honour down\nThat violates the smallest branch herein.\nIf you are arm'd to do as sworn to do,\nSubscribe to your deep oaths, and keep it too.\nYour oath is pass'd to pass away from these.", shape=(), dtype=string)
# tf.Tensor(b'this?\nDid you hear the proclamation?', shape=(), dtype=string)

# %%
# Input pre-processing parameters
SEQ_LENGTH = 100
BATCH_SIZE = 8
BUFFER_SIZE = 10000  # For dataset shuffling

# %%
table = tf.contrib.lookup.index_table_from_tensor(
    mapping=vocab,
    num_oov_buckets=0,
    default_value=0)  
  
def to_ids(x):
    s = tf.reshape(x['snippets'], shape=[1])
    chars = tf.string_split(s, delimiter='').values
    ids = table.lookup(chars)
    return ids  

def split_input_target(chunk):
    input_text = tf.map_fn(lambda x: x[:-1], chunk)
    target_text = tf.map_fn(lambda x: x[1:], chunk)
    return BatchType(input_text, target_text)

  
def preprocess(dataset):  
    return (
      # Map ASCII chars to int64 indexes using the vocab
      dataset.map(to_ids)
      # Split into individual chars
      .apply(tf.data.experimental.unbatch())
      # Form example sequences of SEQ_LENGTH +1
      .batch(SEQ_LENGTH + 1,  drop_remainder=True)
      # Shuffle and form minibatches
      .shuffle(BUFFER_SIZE).batch(BATCH_SIZE, drop_remainder=True)
      # And finally split into (input, target) tuples,
      # each of length SEQ_LENGTH.
      .map(split_input_target))

# %%
example_dataset = preprocess(raw_example_dataset)
# print(example_dataset.output_types, example_dataset.output_shapes)  
example_dataset
# Out:
# <DatasetV1Adapter shapes: BatchType(x=(8, 100), y=(8, 100)), types: BatchType(x=tf.int64, y=tf.int64)>

# %%
class FlattenedCategoricalAccuracy(tf.keras.metrics.SparseCategoricalAccuracy):

    def __init__(self, name='accuracy', dtype=None):
        super(FlattenedCategoricalAccuracy, self).__init__(name, dtype=dtype)

    def update_state(self, y_true, y_pred, sample_weight=None):
        y_true = tf.reshape(y_true, [-1, 1])
        y_pred = tf.reshape(y_pred, [-1, len(vocab), 1])
        return super(FlattenedCategoricalAccuracy, self).update_state(
            y_true, y_pred, sample_weight)

# %%
def loss_fn(y_true, y_pred):
    return tf.reduce_mean(
      tf.keras.metrics.sparse_categorical_crossentropy(
          y_true, y_pred, from_logits=True))

# %%
def compile(keras_model):
    keras_model.compile(
      optimizer=gradient_descent.SGD(lr=0.5),
      loss=loss_fn,
      metrics=[FlattenedCategoricalAccuracy()])
    return keras_model

# %%
#@test {"output": "ignore", "timeout": 120}
BATCH_SIZE = 8  # The training and eval batch size for the rest of this tutorial.
keras_model = load_model(batch_size=BATCH_SIZE)

compile(keras_model)

print('Evaluating on an example Shakespeare character:')
keras_model.evaluate(example_dataset.take(1), steps=1)


random_indexes = np.random.randint(
    low=0, high=len(vocab), size=1 * BATCH_SIZE * (SEQ_LENGTH + 1))
data = {
    'snippets':
        tf.constant(''.join(np.array(vocab)[random_indexes]), shape=[1, 1])
}
random_dataset = preprocess(tf.data.Dataset.from_tensor_slices(data))
print('Expected accuracy for random guessing: {:.3f}'.format(1.0 / len(vocab)))
print('Evaluating on completely random data:')
keras_model.evaluate(random_dataset, steps=1)
# Out:
# Evaluating on an example Shakespeare character:
# 1/1 [==============================] - 1s 1s/step - loss: 3.2276 - accuracy: 0.3837
# Expected accuracy for random guessing: 0.012
# Evaluating on completely random data:
# 1/1 [==============================] - 1s 796ms/step - loss: 11.5089 - accuracy: 0.0100
# [11.508935928344727, 0.01]

# %% [markdown]
# # Fine-tune the model with Federated Learning

# %%
def create_tff_model():
    x = tf.constant(np.random.randint(1, len(vocab), size=[BATCH_SIZE, SEQ_LENGTH]))
    dummy_batch = collections.OrderedDict([('x', x), ('y', x)]) 
    keras_model_clone = compile(tf.keras.models.clone_model(keras_model))
    return tff.learning.from_compiled_keras_model(
      keras_model_clone, dummy_batch=dummy_batch)

# %%
fed_avg = tff.learning.build_federated_averaging_process(model_fn=create_tff_model)

# %%
state = fed_avg.initialize()
state, metrics = fed_avg.next(state, [example_dataset.take(1)])
print(metrics)
# Out:
# <accuracy=0.005,loss=4.45424>

# %%
def data(client, source=train_data):
    return preprocess(
      source.create_tf_dataset_for_client(client)).take(2)

clients = ['ALL_S_WELL_THAT_ENDS_WELL_CELIA',
           'MUCH_ADO_ABOUT_NOTHING_OTHELLO',
           'THE_TRAGEDY_OF_KING_LEAR_KING']

train_datasets = [data(client) for client in clients]

# We concatenate the test datasets for evaluation with Keras.
test_dataset = functools.reduce(
    lambda d1, d2: d1.concatenate(d2),
    [data(client, test_data) for client in clients])

# %%
NUM_ROUNDS = 3

state = fed_avg.initialize()

state = tff.learning.state_with_new_model_weights(
    state,
    trainable_weights=[v.numpy() for v in keras_model.trainable_weights],
    non_trainable_weights=[
        v.numpy() for v in keras_model.non_trainable_weights
    ])


def keras_evaluate(state, round_num):
    keras_model.set_weights(
      tff.learning.keras_weights_from_tff_weights(state.model))
    print('Evaluating before training round', round_num)
    keras_model.evaluate(example_dataset, steps=2)


for round_num in range(NUM_ROUNDS):
    keras_evaluate(state, round_num)

keras_evaluate(state, NUM_ROUNDS + 1)
# Out:
# Evaluating before training round 0
# 2/2 [==============================] - 0s 152ms/step - loss: 3.2440 - accuracy: 0.4169
# Training metrics:  <accuracy=0.427083,loss=3.05846>
# Evaluating before training round 1
# 2/2 [==============================] - 0s 153ms/step - loss: 3.0569 - accuracy: 0.4200
# Training metrics:  <accuracy=0.531458,loss=2.15261>
# Evaluating before training round 2
# 2/2 [==============================] - 0s 153ms/step - loss: 2.9532 - accuracy: 0.4294
# Training metrics:  <accuracy=0.633125,loss=1.56697>
# Evaluating before training round 4
# 2/2 [==============================] - 0s 151ms/step - loss: 2.8702 - accuracy: 0.4400

# %%
keras_model_batch1.set_weights([v.numpy() for v in keras_model.weights])
print(generate_text(keras_model_batch1, 'What of TensorFlow Federated, you ask? '))
# Out:
# What of TensorFlow Federated, you ask? Says
# in my cell in the husband and fiffeinne, the hands of the clock, struck him to the chocolate with lists with the rascal public himself.
# What forehead was the golden head that lived it for music;
